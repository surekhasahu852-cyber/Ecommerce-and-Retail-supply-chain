# %%
import pandas as pd

# %%
product=pd.read_csv("products.csv")

# %% [raw]
# suppliers=pd.read_csv("suppliers.csv")

# %%
purchase_orders=pd.read_csv("purchase_orders.csv")

# %%
sales=pd.read_csv("sales.csv")

# %%
inventory_snapshot=pd.read_csv("inventory_snapshot.csv")

# %%
daily_inventory=pd.read_csv("daily_inventory.csv")

# %%
#preview first 5 rows of all tables

# %%
product.head()
# Out:
#           sku_id                   product_name                 category  \
# 0  SKU9310518635         Garnier Sunscreen 50ml                   Beauty
# 1  SKU6955836996  Adidas Running Shoes Standard       Sports & Lifestyle
# 2  SKU6171745695        Puma Gym Towel Standard       Sports & Lifestyle
# 3  SKU9112068923    Samsung Power Bank 10000mAh  Electronics Accessories
# 4  SKU4171552432           Sony USB Charger 33W  Electronics Accessories
#
#            sub_category    brand   product_type size_label launch_date  \
# 0  Skincare & Cosmetics  Garnier      Sunscreen       50ml  2019-04-22
# 1           Sports Gear   Adidas  Running Shoes   Standard  2016-08-13
# 2           Sports Gear     Puma      Gym Towel   Standard  2017-01-26
# 3               Gadgets  Samsung     Power Bank   10000mAh  2019-04-21
# 4               Gadgets     Sony    USB Charger        33W  2016-04-24
#
#    shelf_life_months     parent_sku  default_price  primary_supplier_id  \
# ...

# %%
purchase_orders.head()
# Out:
#    Unnamed: 0       po_id         sku_id  supplier_id     po_date  \
# 0           0  PO03732421  SKU9310518635       200139  2019-05-22
# 1           1  PO72647743  SKU9310518635       200139  2019-06-03
# 2           2  PO41745551  SKU9310518635       200139  2019-09-03
# 3           3  PO95292145  SKU9310518635       200139  2019-12-04
# 4           4  PO94595741  SKU9310518635       200139  2020-03-04
#
#   promised_delivery_date delivery_date  order_qty  unit_cost shipping_mode  \
# 0             2019-06-12    2019-06-18        106      13.65           Air
# 1             2019-06-24    2019-06-27        159      11.37           Air
# 2             2019-09-24    2019-09-19        154      12.03           Air
# 3             2019-12-25    2019-12-21         94      14.15           Air
# 4             2020-03-25    2020-03-25         90      11.42           Air
#
#       status incoterm currency  freight_cost  duty_cost
# 0  delivered      EXW      EUR          7.01      10.44
# ...

# %%
inventory_snapshot.head()
# Out:
#   snapshot_date         sku_id  current_stock  incoming_stock  stock_age_days  \
# 0    2022-12-31  SKU9310518635            360               0             674
# 1    2022-12-31  SKU6955836996            768               0            1165
# 2    2022-12-31  SKU6171745695            915               0            1082
# 3    2022-12-31  SKU9112068923            525               0             675
# 4    2022-12-31  SKU4171552432           1098               0            1221
#
#    warehouse_stock  retail_stock  amazon_allocated  tiktokshop_allocated  \
# 0              280            80                59                    41
# 1              497           271               167                    59
# 2              570           345               187                    77
# 3              338           187                70                    34
# 4              556           542                90                    76
#
# ...

# %%
sales.head()
# Out:
#     sale_id     order_id        date         sku_id     channel  quantity  \
# 0  97746642  ORD97746642  2019-04-22  SKU9310518635      Amazon         1
# 1  98635846  ORD98635846  2019-04-25  SKU9310518635      Amazon         1
# 2  12607411  ORD12607411  2019-04-27  SKU9310518635      Zalora         1
# 3  90411177  ORD90411177  2019-04-28  SKU9310518635  TikTokShop         1
# 4  40822201  ORD40822201  2019-04-28  SKU9310518635      Zalora         2
#
#    unit_price  promo_flag  discount_pct event_name  customer_segment_id  \
# 0       17.74           0           0.0        NaN                    2
# 1       17.74           0           0.0        NaN                    1
# 2       17.74           0           0.0        NaN                    1
# 3       17.74           0           0.0        NaN                    2
# 4       17.74           0           0.0        NaN                    1
#
#   customer_segment device_type payment_method  shipping_fee  voucher_amount  \
# ...

# %%
daily_inventory.head()
# Out:
#   snapshot_date         sku_id  current_stock  daily_sales  incoming_stock  \
# 0    2016-01-01  SKU9310518635             29            0            1606
# 1    2016-01-01  SKU6955836996             29            0            2328
# 2    2016-01-01  SKU6171745695             35            0            2761
# 3    2016-01-01  SKU9112068923              2            0            3371
# 4    2016-01-01  SKU4171552432             24            0            2178
#
#    warehouse_stock  retail_stock  amazon_allocated  tiktokshop_allocated  \
# 0               17            12                 5                     3
# 1               17            12                 5                     3
# 2               21            14                 6                     4
# 3                1             1                 0                     0
# 4               14            10                 4                     2
#
#    zalora_allocated  reorder_point  safety_stock
# ...

# %%
suppliers=pd.read_csv("suppliers.csv")

# %%
suppliers.head(10)
# Out:
#    supplier_id                supplier_name region default_shipping_mode  \
# 0       200856      Unilever Global Markets     UK                   Sea
# 1       200345        Procter & Gamble EMEA     DE                   Sea
# 2       200983     Nestle Consumer Products     MY                  Land
# 3       200099          Samsung Electronics     KR                   Sea
# 4       200271               LG Electronics     KR                   Sea
# 5       200160  Philips Domestic Appliances     NL                   Sea
# 6       200924      Sony Lifestyle Products     JP                   Sea
# 7       200485        IKEA Home Furnishings     SE                   Sea
# 8       200139  L'Oreal Beauty Distribution     FR                   Air
# 9       200889   Johnson & Johnson Consumer     US                   Air
#
#    status lead_time_category  min_order_qty contract_start_date
# 0  active               long            400          2011-01-24
# ...

# %%
#data information

# %%
product.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sku_id               80 non-null     str
#  1   product_name         80 non-null     str
#  2   category             80 non-null     str
#  3   sub_category         80 non-null     str
#  4   brand                80 non-null     str
#  5   product_type         80 non-null     str
#  6   size_label           80 non-null     str
#  7   launch_date          80 non-null     str
#  8   shelf_life_months    26 non-null     float64
#  9   parent_sku           10 non-null     str
#  10  default_price        80 non-null     float64
#  11  primary_supplier_id  80 non-null     int64
#  12  is_active            80 non-null     bool
#  13  country_of_origin    80 non-null     str
#  14  online_only          80 non-null     bool
#  15  avg_rating           80 non-null     float64
# ...

# %%
purchase_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1144 non-null   int64
#  1   po_id                   1144 non-null   str
#  2   sku_id                  1144 non-null   str
#  3   supplier_id             1144 non-null   int64
#  4   po_date                 1144 non-null   str
#  5   promised_delivery_date  1144 non-null   str
#  6   delivery_date           1144 non-null   str
#  7   order_qty               1144 non-null   int64
#  8   unit_cost               1144 non-null   float64
#  9   shipping_mode           1144 non-null   str
#  10  status                  1144 non-null   str
#  11  incoterm                1144 non-null   str
#  12  currency                1144 non-null   str
#  13  freight_cost            1144 non-null   float64
#  14  duty_cost               1144 non-null   float64
# ...

# %%
inventory_snapshot.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   snapshot_date         80 non-null     str
#  1   sku_id                80 non-null     str
#  2   current_stock         80 non-null     int64
#  3   incoming_stock        80 non-null     int64
#  4   stock_age_days        80 non-null     int64
#  5   warehouse_stock       80 non-null     int64
#  6   retail_stock          80 non-null     int64
#  7   amazon_allocated      80 non-null     int64
#  8   tiktokshop_allocated  80 non-null     int64
#  9   zalora_allocated      80 non-null     int64
#  10  reorder_point         80 non-null     int64
#  11  safety_stock          80 non-null     int64
#  12  backorder_qty         80 non-null     int64
#  13  opening_buffer        80 non-null     int64
# dtypes: int64(12), str(2)
# memory usage: 8.9 KB

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 160131 entries, 0 to 160130
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   sale_id              160131 non-null  int64
#  1   order_id             160131 non-null  str
#  2   date                 160131 non-null  str
#  3   sku_id               160131 non-null  str
#  4   channel              160131 non-null  str
#  5   quantity             160131 non-null  int64
#  6   unit_price           160131 non-null  float64
#  7   promo_flag           160131 non-null  int64
#  8   discount_pct         160131 non-null  float64
#  9   event_name           9704 non-null    str
#  10  customer_segment_id  160131 non-null  int64
#  11  customer_segment     160131 non-null  str
#  12  device_type          160131 non-null  str
#  13  payment_method       160131 non-null  str
#  14  shipping_fee         160131 non-null  float64
# ...

# %%
daily_inventory.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 204560 entries, 0 to 204559
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   snapshot_date         204560 non-null  str
#  1   sku_id                204560 non-null  str
#  2   current_stock         204560 non-null  int64
#  3   daily_sales           204560 non-null  int64
#  4   incoming_stock        204560 non-null  int64
#  5   warehouse_stock       204560 non-null  int64
#  6   retail_stock          204560 non-null  int64
#  7   amazon_allocated      204560 non-null  int64
#  8   tiktokshop_allocated  204560 non-null  int64
#  9   zalora_allocated      204560 non-null  int64
#  10  reorder_point         204560 non-null  int64
#  11  safety_stock          204560 non-null  int64
# dtypes: int64(10), str(2)
# memory usage: 18.7 MB

# %%
suppliers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   supplier_id            25 non-null     int64
#  1   supplier_name          25 non-null     str
#  2   region                 25 non-null     str
#  3   default_shipping_mode  25 non-null     str
#  4   status                 25 non-null     str
#  5   lead_time_category     25 non-null     str
#  6   min_order_qty          25 non-null     int64
#  7   contract_start_date    25 non-null     str
# dtypes: int64(2), str(6)
# memory usage: 1.7 KB

# %%
#check missing values

# %%
product.isnull().sum()
# Out:
# sku_id                  0
# product_name            0
# category                0
# sub_category            0
# brand                   0
# product_type            0
# size_label              0
# launch_date             0
# shelf_life_months      54
# parent_sku             70
# default_price           0
# primary_supplier_id     0
# is_active               0
# country_of_origin       0
# online_only             0
# avg_rating              0
# rating_count            0
# is_discontinued         0
# dtype: int64

# %%
purchase_orders.isnull().sum()
# Out:
# Unnamed: 0                0
# po_id                     0
# sku_id                    0
# supplier_id               0
# po_date                   0
# promised_delivery_date    0
# delivery_date             0
# order_qty                 0
# unit_cost                 0
# shipping_mode             0
# status                    0
# incoterm                  0
# currency                  0
# freight_cost              0
# duty_cost                 0
# dtype: int64

# %%
inventory_snapshot.isnull().sum()
# Out:
# snapshot_date           0
# sku_id                  0
# current_stock           0
# incoming_stock          0
# stock_age_days          0
# warehouse_stock         0
# retail_stock            0
# amazon_allocated        0
# tiktokshop_allocated    0
# zalora_allocated        0
# reorder_point           0
# safety_stock            0
# backorder_qty           0
# opening_buffer          0
# dtype: int64

# %%
sales.isnull().sum()
# Out:
# sale_id                     0
# order_id                    0
# date                        0
# sku_id                      0
# channel                     0
# quantity                    0
# unit_price                  0
# promo_flag                  0
# discount_pct                0
# event_name             150427
# customer_segment_id         0
# customer_segment            0
# device_type                 0
# payment_method              0
# shipping_fee                0
# voucher_amount              0
# net_revenue                 0
# returned_flag               0
# quarter_bucket              0
# month                       0
# dtype: int64

# %%
daily_inventory.isnull().sum()
# Out:
# snapshot_date           0
# sku_id                  0
# current_stock           0
# daily_sales             0
# incoming_stock          0
# warehouse_stock         0
# retail_stock            0
# amazon_allocated        0
# tiktokshop_allocated    0
# zalora_allocated        0
# reorder_point           0
# safety_stock            0
# dtype: int64

# %%
suppliers.isnull().sum()
# Out:
# supplier_id              0
# supplier_name            0
# region                   0
# default_shipping_mode    0
# status                   0
# lead_time_category       0
# min_order_qty            0
# contract_start_date      0
# dtype: int64

# %%
#handling missing values

# %%
product['shelf_life_months']=product['shelf_life_months'].fillna(product['shelf_life_months'].median())

# %%
product['parent_sku']=product['parent_sku'].fillna('No parent sku')

# %%
sales['event_name']=sales['event_name'].fillna('No event')

# %%
#check duplicate rows

# %%
product.duplicated().sum()
# Out:
# np.int64(0)

# %%
purchase_orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
inventory_snapshot.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
daily_inventory.duplicated().sum()
# Out:
# np.int64(0)

# %%
suppliers.duplicated().sum()
# Out:
# np.int64(0)

# %%
#remove extra spaces from column names

# %% [raw]
# product.columns=product.columns.str.strip()

# %%
purchase_orders.columns=purchase_orders.columns.str.strip()

# %%
inventory_snapshot.columns=inventory_snapshot.columns.str.strip()

# %%
sales.columns=sales.columns.str.strip()

# %%
daily_inventory.columns=daily_inventory.columns.str.strip()

# %%
suppliers.columns=suppliers.columns.str.strip()

# %%
#data type change

# %%
product['launch_date']=pd.to_datetime(product['launch_date'])

# %%
purchase_orders['po_date']=pd.to_datetime(purchase_orders['po_date'])

# %%
purchase_orders['promised_delivery_date']=pd.to_datetime(purchase_orders['promised_delivery_date'])

# %%
purchase_orders['delivery_date']=pd.to_datetime(purchase_orders['delivery_date'])

# %%
inventory_snapshot['snapshot_date']=pd.to_datetime(inventory_snapshot['snapshot_date'])

# %%
sales['date']=pd.to_datetime(sales['date'])

# %%
daily_inventory['snapshot_date']=pd.to_datetime(daily_inventory['snapshot_date'])

# %%
suppliers['contract_start_date']=pd.to_datetime(suppliers['contract_start_date'])

# %%
#verify missing values

# %%
product.isnull().sum()
# Out:
# sku_id                 0
# product_name           0
# category               0
# sub_category           0
# brand                  0
# product_type           0
# size_label             0
# launch_date            0
# shelf_life_months      0
# parent_sku             0
# default_price          0
# primary_supplier_id    0
# is_active              0
# country_of_origin      0
# online_only            0
# avg_rating             0
# rating_count           0
# is_discontinued        0
# dtype: int64

# %%
sales.isnull().sum()
# Out:
# sale_id                0
# order_id               0
# date                   0
# sku_id                 0
# channel                0
# quantity               0
# unit_price             0
# promo_flag             0
# discount_pct           0
# event_name             0
# customer_segment_id    0
# customer_segment       0
# device_type            0
# payment_method         0
# shipping_fee           0
# voucher_amount         0
# net_revenue            0
# returned_flag          0
# quarter_bucket         0
# month                  0
# dtype: int64

# %%
#verify data types

# %%
product.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sku_id               80 non-null     str
#  1   product_name         80 non-null     str
#  2   category             80 non-null     str
#  3   sub_category         80 non-null     str
#  4   brand                80 non-null     str
#  5   product_type         80 non-null     str
#  6   size_label           80 non-null     str
#  7   launch_date          80 non-null     datetime64[us]
#  8   shelf_life_months    80 non-null     float64
#  9   parent_sku           80 non-null     str
#  10  default_price        80 non-null     float64
#  11  primary_supplier_id  80 non-null     int64
#  12  is_active            80 non-null     bool
#  13  country_of_origin    80 non-null     str
#  14  online_only          80 non-null     bool
#  15  avg_rating           80 non-null     float64
# ...

# %%
purchase_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1144 non-null   int64
#  1   po_id                   1144 non-null   str
#  2   sku_id                  1144 non-null   str
#  3   supplier_id             1144 non-null   int64
#  4   po_date                 1144 non-null   datetime64[us]
#  5   promised_delivery_date  1144 non-null   datetime64[us]
#  6   delivery_date           1144 non-null   datetime64[us]
#  7   order_qty               1144 non-null   int64
#  8   unit_cost               1144 non-null   float64
#  9   shipping_mode           1144 non-null   str
#  10  status                  1144 non-null   str
#  11  incoterm                1144 non-null   str
#  12  currency                1144 non-null   str
#  13  freight_cost            1144 non-null   float64
# ...

# %%
inventory_snapshot.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   snapshot_date         80 non-null     datetime64[us]
#  1   sku_id                80 non-null     str
#  2   current_stock         80 non-null     int64
#  3   incoming_stock        80 non-null     int64
#  4   stock_age_days        80 non-null     int64
#  5   warehouse_stock       80 non-null     int64
#  6   retail_stock          80 non-null     int64
#  7   amazon_allocated      80 non-null     int64
#  8   tiktokshop_allocated  80 non-null     int64
#  9   zalora_allocated      80 non-null     int64
#  10  reorder_point         80 non-null     int64
#  11  safety_stock          80 non-null     int64
#  12  backorder_qty         80 non-null     int64
#  13  opening_buffer        80 non-null     int64
# dtypes: datetime64[us](1), int64(12), str(1)
# memory usage: 8.9 KB

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 160131 entries, 0 to 160130
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   sale_id              160131 non-null  int64
#  1   order_id             160131 non-null  str
#  2   date                 160131 non-null  datetime64[us]
#  3   sku_id               160131 non-null  str
#  4   channel              160131 non-null  str
#  5   quantity             160131 non-null  int64
#  6   unit_price           160131 non-null  float64
#  7   promo_flag           160131 non-null  int64
#  8   discount_pct         160131 non-null  float64
#  9   event_name           160131 non-null  str
#  10  customer_segment_id  160131 non-null  int64
#  11  customer_segment     160131 non-null  str
#  12  device_type          160131 non-null  str
#  13  payment_method       160131 non-null  str
#  14  shipping_fee         160131 non-null  float64
# ...

# %%
daily_inventory.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 204560 entries, 0 to 204559
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   snapshot_date         204560 non-null  datetime64[us]
#  1   sku_id                204560 non-null  str
#  2   current_stock         204560 non-null  int64
#  3   daily_sales           204560 non-null  int64
#  4   incoming_stock        204560 non-null  int64
#  5   warehouse_stock       204560 non-null  int64
#  6   retail_stock          204560 non-null  int64
#  7   amazon_allocated      204560 non-null  int64
#  8   tiktokshop_allocated  204560 non-null  int64
#  9   zalora_allocated      204560 non-null  int64
#  10  reorder_point         204560 non-null  int64
#  11  safety_stock          204560 non-null  int64
# dtypes: datetime64[us](1), int64(10), str(1)
# memory usage: 18.7 MB

# %%
suppliers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   supplier_id            25 non-null     int64
#  1   supplier_name          25 non-null     str
#  2   region                 25 non-null     str
#  3   default_shipping_mode  25 non-null     str
#  4   status                 25 non-null     str
#  5   lead_time_category     25 non-null     str
#  6   min_order_qty          25 non-null     int64
#  7   contract_start_date    25 non-null     datetime64[us]
# dtypes: datetime64[us](1), int64(2), str(5)
# memory usage: 1.7 KB

# %%
#save cleaned dataset

# %%
product.to_csv("product_cleaned.csv")

# %%
purchase_orders.to_csv("purchase_orders_cleaned.csv")

# %%
inventory_snapshot.to_csv("inventory_snapshot_cleaned.csv")

# %%
sales.to_csv("sales_cleaned.csv")

# %%
daily_inventory.to_csv("daily_inventory_cleaned.csv")

# %%
suppliers.to_csv("suppliers_cleaned.csv")

# %%
product_cleaned=pd.read_csv("product_cleaned.csv")
purchase_orders_cleaned=pd.read_csv("purchase_orders_cleaned.csv")
inventory_snapshot_cleaned=pd.read_csv("inventory_snapshot_cleaned.csv")
sales_cleaned=pd.read_csv("sales_cleaned.csv")
daily_inventory_cleaned=pd.read_csv("daily_inventory_cleaned.csv")
suppliers_cleaned=pd.read_csv("suppliers_cleaned.csv")

# %%
import pandas as pd
from sqlalchemy import create_engine
engine=create_engine=("mysql+pymysql://root:surekhasahu%40123@localhost:3306/ECOMMERCE_AND_RETAIL_SUPPLY_CHAIN")
print("starting data transfer to mysql...")
# Out:
# starting data transfer to mysql...

# %%
product.to_sql("product_cleaned",con=engine,if_exists="replace",index=False)
# Out:
# 80

# %%
purchase_orders.to_sql("purchase_orders_cleaned",con=engine,if_exists="replace",index=False)
# Out:
# 1144

# %%
inventory_snapshot.to_sql("inventory_snapshot_cleaned",con=engine,if_exists="replace",index=False)
# Out:
# 80

# %%
sales.to_sql("sales_cleaned",con=engine,if_exists="replace",index=False)
# Out:
# 160131

# %%
daily_inventory.to_sql("daily_inventory_cleaned",con=engine,if_exists="replace",index=False)
# Out:
# 204560

# %%
suppliers.to_sql("suppliers_cleaned",con=engine,if_exists="replace",index=False)
# Out:
# 25
